# %%
import pandas as pd
import glob
import os
import numpy as np
from sqlalchemy import create_engine

path = r'C:\Projects\animalcrossingproject\AC Catalogue'
all_files = glob.glob(os.path.join(path, "*.csv"))

df_from_each_file = (pd.read_csv(f) for f in all_files)
catalogue_df   = pd.concat(df_from_each_file, ignore_index=True)
# Out:
# C:\Users\melan\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # This is added back by InteractiveShellApp.init_path()

# %%
catalogue_df.head()
# Out:
#     #  #1  #2  #3  #4  #5  #6 Artist Award Criteria Birthday  ... VFX Type  \
# 0 NaN NaN NaN NaN NaN NaN NaN    NaN            NaN      NaN  ...      NaN
# 1 NaN NaN NaN NaN NaN NaN NaN    NaN            NaN      NaN  ...      NaN
# 2 NaN NaN NaN NaN NaN NaN NaN    NaN            NaN      NaN  ...      NaN
# 3 NaN NaN NaN NaN NaN NaN NaN    NaN            NaN      NaN  ...      NaN
# 4 NaN NaN NaN NaN NaN NaN NaN    NaN            NaN      NaN  ...      NaN
#
#   Variant ID Variation Version Villager Equippable Wallpaper Weather  \
# 0        NaN     White   1.0.0                 Yes       NaN     NaN
# 1        NaN     Black   1.0.0                 Yes       NaN     NaN
# 2        NaN     Beige   1.0.0                  No       NaN     NaN
# 3        NaN    Yellow   1.0.0                  No       NaN     NaN
# 4        NaN    Yellow   1.0.0                 Yes       NaN     NaN
#
#   Where/How Window Color Window Type
# 0       NaN          NaN         NaN
# 1       NaN          NaN         NaN
# 2       NaN          NaN         NaN
# 3       NaN          NaN         NaN
# 4       NaN          NaN         NaN
#
# [5 rows x 135 columns]
